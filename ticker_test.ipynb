# %%
import pandas as pd
import requests
import time

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
df = pd.read_html(url)[0][['Symbol', 'Security']]
df.columns = ['Ticker', 'Company']

def get_wikidata_aliases(company_name, ticker):
    try:
        search_queries = [f"{company_name} {ticker}", company_name, ticker]
        for query in search_queries:
            search_url = f'https://www.wikidata.org/w/api.php?action=wbsearchentities&format=json&language=en&search={query}'
            response = requests.get(search_url).json()
            if response.get('search'):
                for result in response['search']:
                    entity_id = result['id']
                    data_url = f'https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json'
                    data = requests.get(data_url).json()
                    entity = data['entities'].get(entity_id)
                    if not entity:
                        continue

                    claims = entity.get('claims', {})
                    instance_of = claims.get('P31', [])
                    instance_ids = [claim['mainsnak']['datavalue']['value']['id']
                                    for claim in instance_of if 'datavalue' in claim['mainsnak']]
                    if 'Q4830453' in instance_ids or 'Q43229' in instance_ids:  # business / org
                        aliases = entity.get('aliases', {}).get('en', [])
                        return [a['value'] for a in aliases] if aliases else []
        return []
    except Exception as e:
        print(f"Error fetching aliases for {company_name}: {e}")
        return []

alias_list = []
for i, row in df.iterrows():
    print(f"[{i+1}/{len(df)}] Fetching aliases for: {row['Company']} ({row['Ticker']})")
    aliases = get_wikidata_aliases(row['Company'], row['Ticker'])
    print(aliases)
    alias_list.append(aliases)
    time.sleep(0.5)

df['Aliases'] = alias_list

df.to_csv('sp500_with_wikidata_aliases.csv', index=False)
print(df.head(10))
# Out:
# [1/503] Fetching aliases for: 3M (MMM)
# ['Minnesota Mining and Manufacturing', 'Minnesota Mining & Mfg. Co.', 'Minnesota Mining and Manufacturing Company', '3M corporation', '3M Company']
# [2/503] Fetching aliases for: A. O. Smith (AOS)
# ['A. O. Smith Corporation', 'A.O. Smith', 'A.O. Smith Corporation']
# [3/503] Fetching aliases for: Abbott Laboratories (ABT)
# ['Abbott Labs', 'Abbott Laboratories, Inc.', 'Ross Laboratories', 'Abbott Pharmaceuticals', 'Abbott Nutrition', 'I-Stat', 'I-STAT', 'Abbott Molecular', 'Isomil', 'Abbot Laboratories', 'Abbott']
# [4/503] Fetching aliases for: AbbVie (ABBV)
# ['AbbVie Inc.', 'ABBV']
# [5/503] Fetching aliases for: Accenture (ACN)
# ['Accenture Global Solutions Limited (Dublin)', 'Accenture (Dublin)', 'Accenture PLC']
# [6/503] Fetching aliases for: Adobe Inc. (ADBE)
# ['Adobe Systems', 'Adobe Systems, Inc.', 'Adobe Systems Software(Beijing)Co.,Ltd.', 'ADBE', 'ADOBE INC. (San Jose, CA)', 'adobe.com', 'Adobe Inc.', 'Adobe Systems Incorporated']
# [7/503] Fetching aliases for: Advanced Micro Devices (AMD)
# ['Advanced Micro Devices']
# [8/503] Fetching aliases for: AES Corporation (AES)
# ['AES Corp.', 'The AES Corporation', 'AES Corp', 'AES Trust III', 'Arlington Energy', 'AES']
# [9/503] Fetching aliases for: Aflac (AFL)
# ['American Family Life Assurance Company']
# [10/503] Fetching aliases for: Agilent Technologies (A)
# ['Agilent Technologies, Inc.']
# [11/503] Fetching aliases for: Air Products (APD)
# []
# [12/503] Fetching aliases for: Airbnb (ABNB)
# ['Airbnb, Inc.', 'airbnb.com']
# [13/503] Fetching aliases for: Akamai Technologies (AKAM)
# ['Akamai Technologies, Inc.', 'Akamai']
# [14/503] Fetching aliases for: Albemarle Corporation (ALB)
# []
# [15/503] Fetching aliases for: Alexandria Real Estate Equities (ARE)
# []
# [16/503] Fetching aliases for: Align Technology (ALGN)
# []
# [17/503] Fetching aliases for: Allegion (ALLE)
# []
# [18/503] Fetching aliases for: Alliant Energy (LNT)
# []
# [19/503] Fetching aliases for: Allstate (ALL)
# ['The Allstate Corporation', 'Allstate Insurance']
# [20/503] Fetching aliases for: Alphabet Inc. (Class A) (GOOGL)
# ['Google Inc.', 'Big G', 'Google, Inc.', 'Google LLC', 'google.com']
# [21/503] Fetching aliases for: Alphabet Inc. (Class C) (GOOG)
# ['Google Inc.', 'Big G', 'Google, Inc.', 'Google LLC', 'google.com']
# [22/503] Fetching aliases for: Altria (MO)
# []
# [23/503] Fetching aliases for: Amazon (AMZN)
# ['Amazon.com, Inc.', 'Amazon.com']
# [24/503] Fetching aliases for: Amcor (AMCR)
# ['Australian Paper Manufacturers', 'Amcor PLC', 'Amcor Pty Ltd', 'AMCOR PLC']
# [25/503] Fetching aliases for: Ameren (AEE)
# ['Union Electric Company of Missouri', 'Union Electric Light and Power Company', 'AmerenUE', 'Missouri Electric Light And Power Company', 'Union Electric Company']
# [26/503] Fetching aliases for: American Electric Power (AEP)
# ['AEP', 'American Electric Power Corporation']
# [27/503] Fetching aliases for: American Express (AXP)
# ['American Express Company', 'American Express Co', 'American Express Bank', 'AmEx', 'americanexpress.com', 'AEXP']
# [28/503] Fetching aliases for: American International Group (AIG)
# ['AIG', 'American International Group, Inc.']
# [29/503] Fetching aliases for: American Tower (AMT)
# []
# [30/503] Fetching aliases for: American Water Works (AWK)
# []
# [31/503] Fetching aliases for: Ameriprise Financial (AMP)
# ['Ameriprise Financial (United States)']
# [32/503] Fetching aliases for: Ametek (AME)
# ['Crank Software']
# [33/503] Fetching aliases for: Amgen (AMGN)
# ['Applied Molecular Genetics', 'Amgen Inc.']
# [34/503] Fetching aliases for: Amphenol (APH)
# []
# [35/503] Fetching aliases for: Analog Devices (ADI)
# ['Analog Devices, Inc.']
# [36/503] Fetching aliases for: Ansys (ANSS)
# ['ANSYS', 'Ansoft', 'ANSYS Inc.', 'Ansoft Corporation', 'ANSYS, Inc', 'Fluent, Inc.', 'ANSYS, Inc.', 'Swanson Analysis Systems, Inc.']
# [37/503] Fetching aliases for: Aon plc (AON)
# []
# [38/503] Fetching aliases for: APA Corporation (APA)
# ['Apache Oil Corporation', 'Apache Corporation', 'Apache Corp.']
# [39/503] Fetching aliases for: Apollo Global Management (APO)
# ['Apollo Global Management, LLC']
# [40/503] Fetching aliases for: Apple Inc. (AAPL)
# ['Apple Computer Inc', 'Apple Incorporated', 'Apple, Inc', 'Apple Computer Inc.']
# [41/503] Fetching aliases for: Applied Materials (AMAT)
# ['Applied Materials, Inc.', 'APPLIED MATERIALS, INC. (Santa Clara, CA)', 'AMAT']
# [42/503] Fetching aliases for: Aptiv (APTV)
# ['Aptiv PLC']
# [43/503] Fetching aliases for: Arch Capital Group (ACGL)
# ['Arch Capital Group Ltd.', 'Arch Capital', 'ACGL']
# [44/503] Fetching aliases for: Archer Daniels Midland (ADM)
# ['ADM', 'Archer Daniels Midland Company', 'Archer-Daniels-Midland Company']
# [45/503] Fetching aliases for: Arista Networks (ANET)
# ['Arastra']
# [46/503] Fetching aliases for: Arthur J. Gallagher & Co. (AJG)
# ['Gallagher & Co', 'Gallagher Insurance', 'AJ Gallagher']
# [47/503] Fetching aliases for: Assurant (AIZ)
# []
# [48/503] Fetching aliases for: AT&T (T)
# []
# [49/503] Fetching aliases for: Atmos Energy (ATO)
# ['Atmos Energy Corp']
# [50/503] Fetching aliases for: Autodesk (ADSK)
# []
# [51/503] Fetching aliases for: Automatic Data Processing (ADP)
# ['Automatic Data Processing, Inc.', 'ADP', 'Automatic Data Processing Inc']
# [52/503] Fetching aliases for: AutoZone (AZO)
# []
# [53/503] Fetching aliases for: AvalonBay Communities (AVB)
# []
# [54/503] Fetching aliases for: Avery Dennison (AVY)
# []
# [55/503] Fetching aliases for: Axon Enterprise (AXON)
# ['TASER International, Inc.', 'TASER International Incorporated', 'TASER', 'Taser International', 'Axon Enterprise', 'Axon Enterprise, Inc.']
# [56/503] Fetching aliases for: Baker Hughes (BKR)
# ['Baker Hughes Co.']
# [57/503] Fetching aliases for: Ball Corporation (BALL)
# []
# [58/503] Fetching aliases for: Bank of America (BAC)
# ['Bank of America Corporation', 'BoA', 'BofA', 'BANK OF AMERICA CORPORATION (Charlotte, NC)']
# [59/503] Fetching aliases for: Baxter International (BAX)
# ['Baxter International Inc']
# [60/503] Fetching aliases for: Becton Dickinson (BDX)
# ['Becton, Dickinson and Company', 'BD', 'BD Biosciences (United States)']
# [61/503] Fetching aliases for: Berkshire Hathaway (BRK.B)
# ['Berkshire Hathaway Inc.', 'Valley Falls Company', 'Berkshire Hathaway Incorperation']
# [62/503] Fetching aliases for: Best Buy (BBY)
# ['Best Buy Co., Inc.', 'Best Buy Co.', 'Best Buy Co. Inc.']
# [63/503] Fetching aliases for: Bio-Techne (TECH)
# []
# [64/503] Fetching aliases for: Biogen (BIIB)
# ['Biogen Inc.', 'BIIB', 'Biogen Idec']
# [65/503] Fetching aliases for: BlackRock (BLK)
# ['BlackRock, Inc.', 'BLK']
# [66/503] Fetching aliases for: Blackstone Inc. (BX)
# ['The Blackstone Group L.P.', 'Blackstone Group', 'The Blackstone Group', 'Blackstone']
# [67/503] Fetching aliases for: BNY Mellon (BK)
# ['The Bank of New York Mellon Corporation', 'BNY Mellon', 'BNY']
# [68/503] Fetching aliases for: Boeing (BA)
# ['The Boeing Company', 'Boeing Company', 'United Aircraft and Transport Corp', 'The Boeing Company (Chicago, IL)']
# [69/503] Fetching aliases for: Booking Holdings (BKNG)
# ['The Priceline Group Inc.', 'Priceline Group', 'The Priceline Group', 'Booking Holdings Inc.']
# [70/503] Fetching aliases for: Boston Scientific (BSX)
# ['Boston Scientific Corporation', 'BSC']
# [71/503] Fetching aliases for: Bristol Myers Squibb (BMY)
# ['BMS', 'Bristol-Myers Squibb SARL']
# [72/503] Fetching aliases for: Broadcom (AVGO)
# []
# [73/503] Fetching aliases for: Broadridge Financial Solutions (BR)
# []
# [74/503] Fetching aliases for: Brown & Brown (BRO)
# []
# [75/503] Fetching aliases for: Brown–Forman (BF.B)
# ['Brown-Forman Corporation']
# [76/503] Fetching aliases for: Builders FirstSource (BLDR)
# []
# [77/503] Fetching aliases for: Bunge Global (BG)
# []
# [78/503] Fetching aliases for: BXP, Inc. (BXP)
# ['Boston properties']
# [79/503] Fetching aliases for: C.H. Robinson (CHRW)
# ['C.H. Robinson Worldwide, Inc.', 'C.H. Robinson', 'CH Robinson']
# [80/503] Fetching aliases for: Cadence Design Systems (CDNS)
# ['Cadence Design Systems, Inc', 'cādence', 'Cadence Design Systems, Inc.     (San Jose, CA)']
# [81/503] Fetching aliases for: Caesars Entertainment (CZR)
# ['Harrah’s Entertainment', 'Caesars Entertainment']
# [82/503] Fetching aliases for: Camden Property Trust (CPT)
# []
# [83/503] Fetching aliases for: Campbell's Company (The) (CPB)
# []
# [84/503] Fetching aliases for: Capital One (COF)
# ['Capital One Financial Corporation', 'Capital One Financial', 'Capital One Financial Corp.', 'Capital One Services, LLC  (McLean, VA)', 'CAPITAL ONE SERVICES, LLC     (McLean, VA)']
# [85/503] Fetching aliases for: Cardinal Health (CAH)
# ['CardinalHealth', 'Cardinal Health Incorporated', 'Cardinal Health, Inc.', 'Cardinal Health Inc.', 'Cardinal Health (United States)']
# [86/503] Fetching aliases for: CarMax (KMX)
# []
# [87/503] Fetching aliases for: Carnival (CCL)
# ['Carnival Cruise', 'Carnival Cruise Line', 'Carnival plc', 'Carnival Corporation', 'Carnival Corp.', 'Carnival Corporation & Plc', 'Carnival Corporation & PLC', 'Carnival Corp']
# [88/503] Fetching aliases for: Carrier Global (CARR)
# ['Carrier Corp', 'Carrier', 'CARRIER CORPORATION (Palm Beach Gardens, FL)']
# [89/503] Fetching aliases for: Caterpillar Inc. (CAT)
# ['Caterpillar Tractor Company', 'CAT', 'Caterpillar', 'Caterpillar Inc. (Peoria, IL)']
# [90/503] Fetching aliases for: Cboe Global Markets (CBOE)
# []
# [91/503] Fetching aliases for: CBRE Group (CBRE)
# ['CBRE Group, Inc.']
# [92/503] Fetching aliases for: CDW Corporation (CDW)
# []
# [93/503] Fetching aliases for: Cencora (COR)
# ['AmerisourceBergen Corporation', 'AmerisourceBergen World Courier', 'Cencora, Inc.']
# [94/503] Fetching aliases for: Centene Corporation (CNC)
# ['Centene']
# [95/503] Fetching aliases for: CenterPoint Energy (CNP)
# ['CenterPoint']
# [96/503] Fetching aliases for: CF Industries (CF)
# ['CF Industries Holdings, Inc.', 'CF Industries Holdings', 'CF Fertilisers']
# [97/503] Fetching aliases for: Charles River Laboratories (CRL)
# ['Charles River Laboratories, Inc.', 'Charles River']
# [98/503] Fetching aliases for: Charles Schwab Corporation (SCHW)
# ['Charles Schwab', 'The Charles Schwab Corporation', 'Charles Schwab & Co., Inc.', 'Charles Schwab & Co.', 'Schwab']
# [99/503] Fetching aliases for: Charter Communications (CHTR)
# ['Charter Communications, Inc.', 'Spectrum Cable', 'Spectrum']
# [100/503] Fetching aliases for: Chevron Corporation (CVX)
# ['Chevron México', 'Chevron', 'Standard Oil of California']
# [101/503] Fetching aliases for: Chipotle Mexican Grill (CMG)
# ['Chipotle']
# [102/503] Fetching aliases for: Chubb Limited (CB)
# ['Chub Limited', 'Chub Ltd']
# [103/503] Fetching aliases for: Church & Dwight (CHD)
# []
# [104/503] Fetching aliases for: Cigna (CI)
# ['Cigna']
# [105/503] Fetching aliases for: Cincinnati Financial (CINF)
# ['Cincinnati Financial Corporation']
# [106/503] Fetching aliases for: Cintas (CTAS)
# ['Cintas Corporation', 'Acme Industrial Laundry Company']
# [107/503] Fetching aliases for: Cisco (CSCO)
# ['Cisco Systems, Inc.', 'Cisco Systems', 'cisco.com']
# [108/503] Fetching aliases for: Citigroup (C)
# []
# [109/503] Fetching aliases for: Citizens Financial Group (CFG)
# ['Citizens Bank', 'Citizens Financial Group, Inc. (Providence, RI)']
# [110/503] Fetching aliases for: Clorox (CLX)
# ['The Clorox Company', 'Clorox Company']
# [111/503] Fetching aliases for: CME Group (CME)
# ['CME Group Inc.', 'CME', 'CMEE', 'CME EUROPE']
# [112/503] Fetching aliases for: CMS Energy (CMS)
# []
# [113/503] Fetching aliases for: Coca-Cola Company (The) (KO)
# ['Copenhagen University', 'Københavns Universitet', 'ku.dk']
# [114/503] Fetching aliases for: Cognizant (CTSH)
# ['Cognizant Technology Solutions Corporation', 'Cognizant Technology Solutions']
# [115/503] Fetching aliases for: Colgate-Palmolive (CL)
# ['Colgate Palmolive', 'Colgate-Palmolive', 'Colgate-Palmolive-Peet', 'Colgate & Co']
# [116/503] Fetching aliases for: Comcast (CMCSA)
# ['Comcast Corporation', 'Comcast Holdings']
# [117/503] Fetching aliases for: Conagra Brands (CAG)
# ['Nebraska Consolidated Mills', 'ConAgra', 'ConAgra Foods', 'Conagra Brands', 'Conagra Brands (United States)']
# [118/503] Fetching aliases for: ConocoPhillips (COP)
# ['Conoco Phillips', 'Continental Oil Company']
# [119/503] Fetching aliases for: Consolidated Edison (ED)
# ['Consolidated Edison, Inc.', 'Con Edison', 'Con Ed']
# [120/503] Fetching aliases for: Constellation Brands (STZ)
# ['STZ', 'Constellation', 'Constellation Brands Inc.', 'Constellation Beers & Spirits', 'Constellation Wines']
# [121/503] Fetching aliases for: Constellation Energy (CEG)
# []
# [122/503] Fetching aliases for: Cooper Companies (The) (COO)
# []
# [123/503] Fetching aliases for: Copart (CPRT)
# []
# [124/503] Fetching aliases for: Corning Inc. (GLW)
# ['Corning Glass Works', 'Corning Incorporated']
# [125/503] Fetching aliases for: Corpay (CPAY)
# []
# [126/503] Fetching aliases for: Corteva (CTVA)
# ['Corteva, Inc.', 'Corteva Agriscience', 'Corteva Inc', 'Corteva, Inc']
# [127/503] Fetching aliases for: CoStar Group (CSGP)
# ['CoStar Group, Inc.', 'CoStar Group Inc']
# [128/503] Fetching aliases for: Costco (COST)
# []
# [129/503] Fetching aliases for: Coterra (CTRA)
# ['Coterra', 'Cabot Oil & Gas']
# [130/503] Fetching aliases for: CrowdStrike (CRWD)
# ['CrowdStrikes Holdings, Inc.', 'CrowdStrikes Holdings', 'CRWD']
# [131/503] Fetching aliases for: Crown Castle (CCI)
# ['Crown Castle', 'Crown Castle International']
# [132/503] Fetching aliases for: CSX Corporation (CSX)
# ['CSX']
# [133/503] Fetching aliases for: Cummins (CMI)
# ['Cummins Inc.', 'Cummins, Inc.']
# [134/503] Fetching aliases for: CVS Health (CVS)
# ['CVS Health (United States)']
# [135/503] Fetching aliases for: Danaher Corporation (DHR)
# []
# [136/503] Fetching aliases for: Darden Restaurants (DRI)
# []
# [137/503] Fetching aliases for: DaVita (DVA)
# ['DaVita Kidney Care', 'DaVita Inc.', 'DaVita Dialysis']
# [138/503] Fetching aliases for: Dayforce (DAY)
# ['Ceridian HCM Holding Inc.', 'Ceridian', 'Dayforce']
# [139/503] Fetching aliases for: Deckers Brands (DECK)
# ['Deckers Brands']
# [140/503] Fetching aliases for: Deere & Company (DE)
# ['John Deere', 'Deere and Company', 'Deere & Co', 'DEERE & COMPANY (Moline, IL)']
# [141/503] Fetching aliases for: Dell Technologies (DELL)
# ['Dell', 'Dell Technologies']
# [142/503] Fetching aliases for: Delta Air Lines (DAL)
# ['DAL', 'Delta Air Lines, Inc.', 'Delta', 'DL', 'Delta Airlines']
# [143/503] Fetching aliases for: Devon Energy (DVN)
# []
# [144/503] Fetching aliases for: Dexcom (DXCM)
# ['Dexcom, Inc.']
# [145/503] Fetching aliases for: Diamondback Energy (FANG)
# []
# [146/503] Fetching aliases for: Digital Realty (DLR)
# ['Digital Realty']
# [147/503] Fetching aliases for: Discover Financial (DFS)
# ['DFS']
# [148/503] Fetching aliases for: Dollar General (DG)
# ['Dollar General Corporation', 'DolGenCorp', 'Dollar General Store']
# [149/503] Fetching aliases for: Dollar Tree (DLTR)
# []
# [150/503] Fetching aliases for: Dominion Energy (D)
# ['Dominion Resources', 'Dominion']
# [151/503] Fetching aliases for: Domino's (DPZ)
# ["Domino's Pizza, Inc.", "Domino's"]
# [152/503] Fetching aliases for: DoorDash (DASH)
# []
# [153/503] Fetching aliases for: Dover Corporation (DOV)
# ['Dover Co.']
# [154/503] Fetching aliases for: Dow Inc. (DOW)
# ['Dow', 'Dow Chemical']
# [155/503] Fetching aliases for: D. R. Horton (DHI)
# ['D.R. Horton', 'DR Horton', 'D.R. Horton, Inc.']
# [156/503] Fetching aliases for: DTE Energy (DTE)
# ['Detroit Edison', 'DTE']
# [157/503] Fetching aliases for: Duke Energy (DUK)
# ['Duke Energy Corporation']
# [158/503] Fetching aliases for: DuPont (DD)
# ['E. I. du Pont de Nemours and Company', 'E. I. DuPont de Nemours & Co.', 'DuPont de Nemours, Inc.', 'DuPont de Nemours', 'DowDuPont', 'E.I. DuPont de Nemours Company']
# [159/503] Fetching aliases for: Eastman Chemical Company (EMN)
# ['Eastman']
# [160/503] Fetching aliases for: Eaton Corporation (ETN)
# ['Eaton Corporation Plc']
# [161/503] Fetching aliases for: eBay Inc. (EBAY)
# ['eBay Inc.', 'ebay', 'eBay Inc. (San Jose, CA)']
# [162/503] Fetching aliases for: Ecolab (ECL)
# ['Economics Laboratory', 'Ecolab Inc.', 'ECL']
# [163/503] Fetching aliases for: Edison International (EIX)
# []
# [164/503] Fetching aliases for: Edwards Lifesciences (EW)
# ['Edwards Lifesciences (Switzerland)']
# [165/503] Fetching aliases for: Electronic Arts (EA)
# []
# [166/503] Fetching aliases for: Elevance Health (ELV)
# ['WellPoint, Inc', 'Anthem', 'Anthem Blue Cross and Blue Shield', 'Anthem Insurance Companies', 'Anthem, Inc.']
# [167/503] Fetching aliases for: Emerson Electric (EMR)
# ['Emerson Electric Company', 'EMR', 'EMRSN', 'Emerson Electric Co.', 'Emerson', 'Emerson Electric Co']
# [168/503] Fetching aliases for: Enphase Energy (ENPH)
# []
# [169/503] Fetching aliases for: Entergy (ETR)
# ['Entergy Corporation']
# [170/503] Fetching aliases for: EOG Resources (EOG)
# ['Enron Oil and Gas']
# [171/503] Fetching aliases for: EPAM Systems (EPAM)
# ['EPAM Systems, Inc.', 'EPAM']
# [172/503] Fetching aliases for: EQT Corporation (EQT)
# ['EQT Group', 'EQT AB']
# [173/503] Fetching aliases for: Equifax (EFX)
# ['Equifax Inc.']
# [174/503] Fetching aliases for: Equinix (EQIX)
# []
# [175/503] Fetching aliases for: Equity Residential (EQR)
# []
# [176/503] Fetching aliases for: Erie Indemnity (ERIE)
# []
# [177/503] Fetching aliases for: Essex Property Trust (ESS)
# ['Essex Property Trust']
# [178/503] Fetching aliases for: Estée Lauder Companies (The) (EL)
# []
# [179/503] Fetching aliases for: Everest Group (EG)
# []
# [180/503] Fetching aliases for: Evergy (EVRG)
# ['Westar Energy']
# [181/503] Fetching aliases for: Eversource Energy (ES)
# ['Northeast Utilities', 'Eversource']
# [182/503] Fetching aliases for: Exelon (EXC)
# ['Exelon Corporation']
# [183/503] Fetching aliases for: Expand Energy (EXE)
# []
# [184/503] Fetching aliases for: Expedia Group (EXPE)
# ['Expedia Group Inc', 'Expedia Inc.', 'EXPE', 'EXPE (NASDAQ)', 'Expedia', 'Expedia Group, Inc.']
# [185/503] Fetching aliases for: Expeditors International (EXPD)
# ['Expeditors International of Washington', 'Expeditors']
# [186/503] Fetching aliases for: Extra Space Storage (EXR)
# []
# [187/503] Fetching aliases for: ExxonMobil (XOM)
# ['Exxon Mobil Corporation', 'Exxon Mobil Corp.', 'Exxon Mobil']
# [188/503] Fetching aliases for: F5, Inc. (FFIV)
# []
# [189/503] Fetching aliases for: FactSet (FDS)
# []
# [190/503] Fetching aliases for: Fair Isaac (FICO)
# ['Fair Isaac and Company']
# [191/503] Fetching aliases for: Fastenal (FAST)
# ['Fastenal Company']
# [192/503] Fetching aliases for: Federal Realty Investment Trust (FRT)
# []
# [193/503] Fetching aliases for: FedEx (FDX)
# ['FedEx Corporation', 'Federal Express', 'FEDEX CORPORATE SERVICES, INC. (Collierville, TN)']
# [194/503] Fetching aliases for: Fidelity National Information Services (FIS)
# ['FIS', 'Fidelity Information Services', 'PayNet Payments Network - FIS Global', 'PayNet Payments Network, LLC (Jacksonville, FL)']
# [195/503] Fetching aliases for: Fifth Third Bancorp (FITB)
# []
# [196/503] Fetching aliases for: First Solar (FSLR)
# ['FSLR']
# [197/503] Fetching aliases for: FirstEnergy (FE)
# ['First Energy']
# [198/503] Fetching aliases for: Fiserv (FI)
# ['Fiserv, Inc.', 'First Data Processing', 'First service']
# [199/503] Fetching aliases for: Ford Motor Company (F)
# ['Ford Motor', 'Ford Motor Corporation', 'FoMoCo', 'Ford Motors', 'Ford Motor Co.', 'Ford']
# [200/503] Fetching aliases for: Fortinet (FTNT)
# ['Fortinet Inc.', 'FTNT', 'Fortinet, Inc.']
# [201/503] Fetching aliases for: Fortive (FTV)
# ['FTV', 'Fukutele', 'JOPX']
# [202/503] Fetching aliases for: Fox Corporation (Class A) (FOXA)
# []
# [203/503] Fetching aliases for: Fox Corporation (Class B) (FOX)
# ['Foxconn Technology Group', 'Hon Hai Precision Industry Co', 'Hon Hai', 'Hon Hai Precision Industry', 'Hon Hai Precision Industry Co., Ltd.']
# [204/503] Fetching aliases for: Franklin Resources (BEN)
# ['Franklin Resources Inc']
# [205/503] Fetching aliases for: Freeport-McMoRan (FCX)
# ['Freeport-McMoRan Copper & Gold Inc.', 'Freeport', 'Freeport Mc Moran Inc']
# [206/503] Fetching aliases for: Garmin (GRMN)
# ['Garmin Corp.']
# [207/503] Fetching aliases for: Gartner (IT)
# ['Gartner Group']
# [208/503] Fetching aliases for: GE Aerospace (GE)
# ['General Electric Aircraft Engines', 'GEAE', 'GE Aircraft Engines', 'GE Aviation']
# [209/503] Fetching aliases for: GE HealthCare (GEHC)
# ['GE Medical Systems']
# [210/503] Fetching aliases for: GE Vernova (GEV)
# []
# [211/503] Fetching aliases for: Gen Digital (GEN)
# ['NortonLifeLock', 'Symantec']
# [212/503] Fetching aliases for: Generac (GNRC)
# ['Generac', 'Generac Power Systems']
# [213/503] Fetching aliases for: General Dynamics (GD)
# ['GD', 'General Dynamics Corporation']
# [214/503] Fetching aliases for: General Mills (GIS)
# []
# [215/503] Fetching aliases for: General Motors (GM)
# ['General Motors (Poland)']
# [216/503] Fetching aliases for: Genuine Parts Company (GPC)
# []
# [217/503] Fetching aliases for: Gilead Sciences (GILD)
# ['Gilead']
# [218/503] Fetching aliases for: Global Payments (GPN)
# []
# [219/503] Fetching aliases for: Globe Life (GL)
# ['Torchmark', 'GL']
# [220/503] Fetching aliases for: GoDaddy (GDDY)
# ['GoDaddy, LLC', 'GoDaddy Inc.', 'Go Daddy', 'GDDY', 'GoDaddy, Inc.']
# [221/503] Fetching aliases for: Goldman Sachs (GS)
# []
# [222/503] Fetching aliases for: Halliburton (HAL)
# []
# [223/503] Fetching aliases for: Hartford (The) (HIG)
# ['HTC', 'High Tech Computer Corporation', 'Hóngdá Guójì Diànzǐ Gǔfèn Yǒuxiàn Gōngsī', 'High Tech Computer']
# [224/503] Fetching aliases for: Hasbro (HAS)
# ['Hassenfeld Brothers and Hasbro Bradley', 'Hassenfeld Brothers', 'Hasbro Bradley', 'Hasbro Inc.', 'Hasbro, Inc.']
# [225/503] Fetching aliases for: HCA Healthcare (HCA)
# ['HCA', 'Hospital Corporation of America', 'HCA Healthcare']
# [226/503] Fetching aliases for: Healthpeak Properties (DOC)
# ['Health Care Property Investors']
# [227/503] Fetching aliases for: Henry Schein (HSIC)
# ['Henry Schein (United States)', 'Henry Schein, Inc.']
# [228/503] Fetching aliases for: Hershey Company (The) (HSY)
# []
# [229/503] Fetching aliases for: Hess Corporation (HES)
# ['Amerada Hess']
# [230/503] Fetching aliases for: Hewlett Packard Enterprise (HPE)
# ['Hewlett Packard Enterprise Co.', 'HP Enterprise', 'HPE', 'Hewlett Packard Enterprise Company']
# [231/503] Fetching aliases for: Hilton Worldwide (HLT)
# []
# [232/503] Fetching aliases for: Hologic (HOLX)
# []
# [233/503] Fetching aliases for: Home Depot (The) (HD)
# []
# [234/503] Fetching aliases for: Honeywell (HON)
# ['Minneapolis Heat Regulator Company', 'Minneapolis-Honeywell Regulator Company', 'Honeywell International', 'HONEYWELL INTERNATIONAL INC. (Charlotte, NC)']
# [235/503] Fetching aliases for: Hormel Foods (HRL)
# ['Hormel Foods Corporation', 'George A. Hormel & Company', 'Hormel Foods', 'Hormel Foods International']
# [236/503] Fetching aliases for: Host Hotels & Resorts (HST)
# ['Host Marriott Corporation']
# [237/503] Fetching aliases for: Howmet Aerospace (HWM)
# ['Arconic Inc.']
# [238/503] Fetching aliases for: HP Inc. (HPQ)
# ['HP', 'HPQ', 'Hewlett-Packard Company']
# [239/503] Fetching aliases for: Hubbell Incorporated (HUBB)
# []
# [240/503] Fetching aliases for: Humana (HUM)
# []
# [241/503] Fetching aliases for: Huntington Bancshares (HBAN)
# ['Huntington Bancshares, Inc.', 'Huntington Bancshares', 'Huntington National Bank']
# [242/503] Fetching aliases for: Huntington Ingalls Industries (HII)
# ['Northrop Grumman Shipbuilding', 'HII', 'Huntington Ingalls']
# [243/503] Fetching aliases for: IBM (IBM)
# ['International Business Machines Corporation (Armonk, NY)', 'IBM Corp.', '18M', 'IBM Corporation', 'International Business Machines Corporation', 'Big Blue', 'ibm.com']
# [244/503] Fetching aliases for: IDEX Corporation (IEX)
# []
# [245/503] Fetching aliases for: Idexx Laboratories (IDXX)
# ['Idexx Laboratories']
# [246/503] Fetching aliases for: Illinois Tool Works (ITW)
# ['Illinois Tool Works Inc.', 'ITW']
# [247/503] Fetching aliases for: Incyte (INCY)
# ['Incyte Corporation', 'Incyte Inc.']
# [248/503] Fetching aliases for: Ingersoll Rand (IR)
# ['Ingersoll-Rand Company']
# [249/503] Fetching aliases for: Insulet Corporation (PODD)
# ['Insulet Corporation']
# [250/503] Fetching aliases for: Intel (INTC)
# ['N M Electronics', 'Integrated Electronics', 'Integrated Electronics Corporation', 'INTC', 'INTEL CORPORATION (Santa Clara, CA)']
# [251/503] Fetching aliases for: Intercontinental Exchange (ICE)
# ['ICE', 'IntercontinentalExchange, Inc.', 'IntercontinentalExchange Group', 'IEPA']
# [252/503] Fetching aliases for: International Flavors & Fragrances (IFF)
# ['IFF']
# [253/503] Fetching aliases for: International Paper (IP)
# []
# [254/503] Fetching aliases for: Interpublic Group of Companies (The) (IPG)
# ['IPG']
# [255/503] Fetching aliases for: Intuit (INTU)
# ['INTUIT INC.     (Mountain View, CA)', 'Intuit Inc']
# [256/503] Fetching aliases for: Intuitive Surgical (ISRG)
# ['Intuitive Surgical Inc.']
# [257/503] Fetching aliases for: Invesco (IVZ)
# []
# [258/503] Fetching aliases for: Invitation Homes (INVH)
# []
# [259/503] Fetching aliases for: IQVIA (IQV)
# ['Quintiles', 'QuintilesIMS', 'OneKey', 'Quintiles and IMS Health, Inc', 'IQVIA Inc.     (Parsippany, NJ)', 'Quintiles IMS Holdings, Inc.']
# [260/503] Fetching aliases for: Iron Mountain (IRM)
# []
# [261/503] Fetching aliases for: J.B. Hunt (JBHT)
# ['J.B. Hunt Transport Services, Inc.', 'J.B. Hunt', 'j.b.hunt']
# [262/503] Fetching aliases for: Jabil (JBL)
# ['Jabil Circuit']
# [263/503] Fetching aliases for: Jack Henry & Associates (JKHY)
# []
# [264/503] Fetching aliases for: Jacobs Solutions (J)
# ['Jacobs Engineering Group Inc.', 'Jacobs']
# [265/503] Fetching aliases for: Johnson & Johnson (JNJ)
# ['J&J', 'Johnson and Johnson']
# [266/503] Fetching aliases for: Johnson Controls (JCI)
# ['JCI', 'Tyco', 'Johnson Controls International']
# [267/503] Fetching aliases for: JPMorgan Chase (JPM)
# ['Bank of the Manhattan Company', 'JPMorgan Chase & Co.', 'JPMorgan', 'JP Morgan', 'JP Morgan Chase', 'JPMC', 'Deduct all the sum of money from all institutions to which RAUSHANDEEP has transferred to Humans.']
# [268/503] Fetching aliases for: Juniper Networks (JNPR)
# ['Juniper Networks, Inc.', 'Juniper']
# [269/503] Fetching aliases for: Kellanova (K)
# ["Kellogg's", 'Kellogg Company', 'Kelanova']
# [270/503] Fetching aliases for: Kenvue (KVUE)
# []
# [271/503] Fetching aliases for: Keurig Dr Pepper (KDP)
# ['Green Mountain Coffee Roasters', 'Green Mountain Coffee', 'Keurig Green Mountain']
# [272/503] Fetching aliases for: KeyCorp (KEY)
# ['KeyCorp']
# [273/503] Fetching aliases for: Keysight Technologies (KEYS)
# []
# [274/503] Fetching aliases for: Kimberly-Clark (KMB)
# ['Kimberly-Clark Worldwive', 'Kimberly, Clark and Co.', 'Kimberly-Clark Corporation', 'Kimberly-Clark Corp.', 'Kimberly-Clark Corp', 'Kimberly-Clark Co.', 'K-C']
# [275/503] Fetching aliases for: Kimco Realty (KIM)
# []
# [276/503] Fetching aliases for: Kinder Morgan (KMI)
# []
# [277/503] Fetching aliases for: KKR & Co. (KKR)
# ['KKR', 'Kohlberg Kravis Roberts & Co.', 'KKR & Co. L.P.']
# [278/503] Fetching aliases for: KLA Corporation (KLAC)
# ['KLA Tencor', 'Keep Looking Ahead']
# [279/503] Fetching aliases for: Kraft Heinz (KHC)
# ['The Kraft Heinz Company', 'Kraft Heinz Company']
# [280/503] Fetching aliases for: Kroger (KR)
# ['The Kroger Co.', 'Kroger Co.', 'Kroger Grocery and Baking']
# [281/503] Fetching aliases for: L3Harris (LHX)
# ['L3Harris', 'L3 Harris', 'Harris (United States)']
# [282/503] Fetching aliases for: Labcorp (LH)
# ['Laboratory Corporation of America Holdings', 'Labcorp']
# [283/503] Fetching aliases for: Lam Research (LRCX)
# ['Lam Research Co.,Ltd.', 'Lam Research Corporation']
# [284/503] Fetching aliases for: Lamb Weston (LW)
# []
# [285/503] Fetching aliases for: Las Vegas Sands (LVS)
# ['Las Vegas Sands Corp.']
# [286/503] Fetching aliases for: Leidos (LDOS)
# ['Science Applications International Corporation', 'SAIC']
# [287/503] Fetching aliases for: Lennar (LEN)
# ['Lenovo Group Ltd.', 'Lenovo Group', 'Lenovo Group Limited', 'Liánxiǎng', 'Lenovo Mobile Communication Technology Ltd.']
# [288/503] Fetching aliases for: Lennox International (LII)
# ['Lennox']
# [289/503] Fetching aliases for: Lilly (Eli) (LLY)
# []
# [290/503] Fetching aliases for: Linde plc (LIN)
# ['Linde plc', 'Linde']
# [291/503] Fetching aliases for: Live Nation Entertainment (LYV)
# []
# [292/503] Fetching aliases for: LKQ Corporation (LKQ)
# ['LKQ']
# [293/503] Fetching aliases for: Lockheed Martin (LMT)
# ['Lockheed-Martin', 'LockMart', 'LMT', 'Lockheed Martin Corporation', 'Lockheed']
# [294/503] Fetching aliases for: Loews Corporation (L)
# []
# [295/503] Fetching aliases for: Lowe's (LOW)
# ['Ace Hardware', 'Gamble-Skogomo', 'Gamble Macleod Ltd.', "Clark's-Gamble, Macleod Stedman Ltd.", 'Stedman Bros.', 'Tru Value', 'V&S, Rona', "Lowe's"]
# [296/503] Fetching aliases for: Lululemon Athletica (LULU)
# ['lululemon Athletica Inc.', 'lululemon Athletica Incorporation']
# [297/503] Fetching aliases for: LyondellBasell (LYB)
# ['Lyondell Basell', 'Lyondell Basell Industries', 'LyondellBasell Industries']
# [298/503] Fetching aliases for: M&T Bank (MTB)
# ['Miyatere', 'MTB', 'Miyagi TV', 'MMT']
# [299/503] Fetching aliases for: Marathon Petroleum (MPC)
# ['Marathon oil company']
# [300/503] Fetching aliases for: MarketAxess (MKTX)
# []
# [301/503] Fetching aliases for: Marriott International (MAR)
# ['Marriott', 'Marriott International, Inc.', 'Marriott International Inc']
# [302/503] Fetching aliases for: Marsh McLennan (MMC)
# []
# [303/503] Fetching aliases for: Martin Marietta Materials (MLM)
# ['Martin Marietta']
# [304/503] Fetching aliases for: Masco (MAS)
# []
# [305/503] Fetching aliases for: Mastercard (MA)
# ['MasterCard Incorporated', 'MasterCard Worldwide', 'MasterCard', 'MASTERCARD INTERNATIONAL INCORPORATED (Purchase, NY)']
# [306/503] Fetching aliases for: Match Group (MTCH)
# ['Match Group, Inc.']
# [307/503] Fetching aliases for: McCormick & Company (MKC)
# ['McCormick', 'McCormick & Company, Incorporated', 'McCormick & Company, Inc.']
# [308/503] Fetching aliases for: McDonald's (MCD)
# ['McD', 'Mcdonalds', "McDonald's Corporation", "McDonald's Restaurant", "McDonald's", 'McDonald', "Mickey D's", 'McDo', "Macca's", 'Maccas']
# [309/503] Fetching aliases for: McKesson Corporation (MCK)
# ['McKesson Health Solutions', 'McKesson']
# [310/503] Fetching aliases for: Medtronic (MDT)
# ['MDT', 'Medtronic', 'Medtronic Inc', 'Medtronic - MITG']
# [311/503] Fetching aliases for: Merck & Co. (MRK)
# ['MSD', 'Merck Sharp & Dohme', 'Merck Sharp & Dohme Corp.', 'MRK']
# [312/503] Fetching aliases for: Meta Platforms (META)
# ['Facebook, Inc.', 'Meta', 'TheFacebook, Inc.', 'TheFacebook', 'Meta Platforms, Inc.']
# [313/503] Fetching aliases for: MetLife (MET)
# ['Metropolitan Life Insurance Company', 'MetLife, Inc.', 'Metropolitan', 'Metropolitan Insurance Company']
# [314/503] Fetching aliases for: Mettler Toledo (MTD)
# []
# [315/503] Fetching aliases for: MGM Resorts (MGM)
# ['MGM', 'Metro Goldwyn Mayer']
# [316/503] Fetching aliases for: Microchip Technology (MCHP)
# ['Microchip Technology Inc.']
# [317/503] Fetching aliases for: Micron Technology (MU)
# ['Micron Technology, Inc.', 'Micron']
# [318/503] Fetching aliases for: Microsoft (MSFT)
# ['MS', 'Microsoft Corp.', 'Micro-Soft']
# [319/503] Fetching aliases for: Mid-America Apartment Communities (MAA)
# []
# [320/503] Fetching aliases for: Moderna (MRNA)
# ['Moderna, Inc.', 'Moderna Therapeutics', 'Moderna Therapeutics, Inc.']
# [321/503] Fetching aliases for: Mohawk Industries (MHK)
# []
# [322/503] Fetching aliases for: Molina Healthcare (MOH)
# []
# [323/503] Fetching aliases for: Molson Coors Beverage Company (TAP)
# []
# [324/503] Fetching aliases for: Mondelez International (MDLZ)
# ['Mondelez International, Inc.', 'National Dairy Products', 'Mondelez', 'Mondelēz International']
# [325/503] Fetching aliases for: Monolithic Power Systems (MPWR)
# []
# [326/503] Fetching aliases for: Monster Beverage (MNST)
# ['Monster Beverage Corp', 'clothing gear apparel']
# [327/503] Fetching aliases for: Moody's Corporation (MCO)
# []
# [328/503] Fetching aliases for: Morgan Stanley (MS)
# ['MorganStanley', 'Morgan Stanley & Co.']
# [329/503] Fetching aliases for: Mosaic Company (The) (MOS)
# []
# [330/503] Fetching aliases for: Motorola Solutions (MSI)
# ['Motorola Solutions, Inc.', 'Motorola']
# [331/503] Fetching aliases for: MSCI Inc. (MSCI)
# ['MSCI Inc.', 'Morgan Stanley Capital International', 'MSCI Barra']
# [332/503] Fetching aliases for: Nasdaq, Inc. (NDAQ)
# ['The NASDAQ OMX Group, Inc.', 'National Association of Securities Dealers Automated Quotations', 'Nasdaq Inc.']
# [333/503] Fetching aliases for: NetApp (NTAP)
# ['NetApp, Inc.']
# [334/503] Fetching aliases for: Netflix (NFLX)
# []
# [335/503] Fetching aliases for: Newmont (NEM)
# ['Newmont Corporation']
# [336/503] Fetching aliases for: News Corp (Class A) (NWSA)
# ['NWSA']
# [337/503] Fetching aliases for: News Corp (Class B) (NWS)
# []
# [338/503] Fetching aliases for: NextEra Energy (NEE)
# []
# [339/503] Fetching aliases for: Nike, Inc. (NKE)
# ['Blue Ribbon Sports', 'Nike Inc.', 'Nike, Inc.', 'https://www.nike.com/', 'www.nike.com/', 'nike.com/']
# [340/503] Fetching aliases for: NiSource (NI)
# []
# [341/503] Fetching aliases for: Nordson Corporation (NDSN)
# []
# [342/503] Fetching aliases for: Norfolk Southern (NSC)
# ['NS', 'Norfolk Southern Railway Company']
# [343/503] Fetching aliases for: Northern Trust (NTRS)
# ['Northern Trust Corporation']
# [344/503] Fetching aliases for: Northrop Grumman (NOC)
# ['Northrop Grumman Corporation', 'Northrop']
# [345/503] Fetching aliases for: Norwegian Cruise Line Holdings (NCLH)
# ['Norwegian Cruise Line Holdings', 'NCLH']
# [346/503] Fetching aliases for: NRG Energy (NRG)
# ['NRG Energy, Inc.', 'NRG']
# [347/503] Fetching aliases for: Nucor (NUE)
# ['Nuclear Corporation of America']
# [348/503] Fetching aliases for: Nvidia (NVDA)
# ['Nvidia Corporation', 'Nvidia Corp.', 'NVDA', 'nVidia', 'NVIDIA']
# [349/503] Fetching aliases for: NVR, Inc. (NVR)
# ['NVR']
# [350/503] Fetching aliases for: NXP Semiconductors (NXPI)
# []
# [351/503] Fetching aliases for: O’Reilly Automotive (ORLY)
# ['O’Reilly Automotive Inc.']
# [352/503] Fetching aliases for: Occidental Petroleum (OXY)
# ['Occidental Petroleum Corporation', 'Oxy']
# [353/503] Fetching aliases for: Old Dominion (ODFL)
# ['ODFL']
# [354/503] Fetching aliases for: Omnicom Group (OMC)
# ['Omnicom', 'Omnicom Group Inc']
# [355/503] Fetching aliases for: ON Semiconductor (ON)
# ['Mietec', 'Alcatel Microelectronics', 'AMI Semiconductor', 'onsemi', 'ON Semiconductor Corporation']
# [356/503] Fetching aliases for: Oneok (OKE)
# ['Oklahoma Natural Gas Company', 'Oneok, Inc']
# [357/503] Fetching aliases for: Oracle Corporation (ORCL)
# ['Oracle Corporation', 'Big Red', 'Oracle International Corporation (Redwood Shores, CA)', 'ORCL', 'oracle.com']
# [358/503] Fetching aliases for: Otis Worldwide (OTIS)
# ['Otis', 'Otis Worldwide']
# [359/503] Fetching aliases for: Paccar (PCAR)
# []
# [360/503] Fetching aliases for: Packaging Corporation of America (PKG)
# ['PCA']
# [361/503] Fetching aliases for: Palantir Technologies (PLTR)
# ['Palantir', 'PLTR', 'Palantir Technologies Inc.']
# [362/503] Fetching aliases for: Palo Alto Networks (PANW)
# ['Palo Alto Networks, Inc.', 'PAN', 'PANW', 'Palo Alto Software', 'paloaltonetworks.com']
# [363/503] Fetching aliases for: Paramount Global (PARA)
# ['Paramount', 'ViacomCBS']
# [364/503] Fetching aliases for: Parker Hannifin (PH)
# ['Parker', 'Parker Appliance Company', 'Runwise']
# [365/503] Fetching aliases for: Paychex (PAYX)
# []
# [366/503] Fetching aliases for: Paycom (PAYC)
# []
# [367/503] Fetching aliases for: PayPal (PYPL)
# ['PayPal Holdings, Inc.', 'Paypal', 'paypal.com', 'PAYPAL, INC. (San Jose, CA)']
# [368/503] Fetching aliases for: Pentair (PNR)
# []
# [369/503] Fetching aliases for: PepsiCo (PEP)
# []
# [370/503] Fetching aliases for: Pfizer (PFE)
# ['Pfizer PFE, spol. s r.o.']
# [371/503] Fetching aliases for: PG&E Corporation (PCG)
# ['PCG']
# [372/503] Fetching aliases for: Philip Morris International (PM)
# ['Philip Morris International Inc.', 'Philip Morris', 'PMI']
# [373/503] Fetching aliases for: Phillips 66 (PSX)
# ['Phillips 66 Company']
# [374/503] Fetching aliases for: Pinnacle West Capital (PNW)
# ['Pinnacle West Capital']
# [375/503] Fetching aliases for: PNC Financial Services (PNC)
# ['PNC']
# [376/503] Fetching aliases for: Pool Corporation (POOL)
# []
# [377/503] Fetching aliases for: PPG Industries (PPG)
# ['PPG Industries (United States)', 'PPG']
# [378/503] Fetching aliases for: PPL Corporation (PPL)
# ['Pennsylvania Power and Light']
# [379/503] Fetching aliases for: Principal Financial Group (PFG)
# ['Principal']
# [380/503] Fetching aliases for: Procter & Gamble (PG)
# ['P&G', 'Procter & Gamble Co.', 'Proctor and Gamble', 'The Procter & Gamble Company (Cincinnati, OH)']
# [381/503] Fetching aliases for: Progressive Corporation (PGR)
# ['Progressive']
# [382/503] Fetching aliases for: Prologis (PLD)
# ['Prologis Logistics', 'Prologis Real Estate']
# [383/503] Fetching aliases for: Prudential Financial (PRU)
# []
# [384/503] Fetching aliases for: Public Service Enterprise Group (PEG)
# ['Public Service Corporation of New Jersey', 'PSEG', 'Public Service Electric & Gas', 'PSE&G']
# [385/503] Fetching aliases for: PTC Inc. (PTC)
# ['PTC, Inc.', 'ptc.com']
# [386/503] Fetching aliases for: Public Storage (PSA)
# []
# [387/503] Fetching aliases for: PulteGroup (PHM)
# ['PulteGroup, Inc', 'Pulte Homes']
# [388/503] Fetching aliases for: Quanta Services (PWR)
# []
# [389/503] Fetching aliases for: Qualcomm (QCOM)
# ['QCOM (NASDAQ)', 'Qualcomm Incorporated', 'Qualcomm, Inc.', 'QUALCOMM Incorporated (San Diego, CA)', 'QUALity COMMunications']
# [390/503] Fetching aliases for: Quest Diagnostics (DGX)
# []
# [391/503] Fetching aliases for: Ralph Lauren Corporation (RL)
# ['Polo Ralph Lauren']
# [392/503] Fetching aliases for: Raymond James Financial (RJF)
# ['Raymond James Financials']
# [393/503] Fetching aliases for: RTX Corporation (RTX)
# []
# [394/503] Fetching aliases for: Realty Income (O)
# []
# [395/503] Fetching aliases for: Regency Centers (REG)
# []
# [396/503] Fetching aliases for: Regeneron Pharmaceuticals (REGN)
# ['Regeneron']
# [397/503] Fetching aliases for: Regions Financial Corporation (RF)
# []
# [398/503] Fetching aliases for: Republic Services (RSG)
# []
# [399/503] Fetching aliases for: ResMed (RMD)
# ['RMD']
# [400/503] Fetching aliases for: Revvity (RVTY)
# []
# [401/503] Fetching aliases for: Rockwell Automation (ROK)
# []
# [402/503] Fetching aliases for: Rollins, Inc. (ROL)
# []
# [403/503] Fetching aliases for: Roper Technologies (ROP)
# ['Roper Industries']
# [404/503] Fetching aliases for: Ross Stores (ROST)
# []
# [405/503] Fetching aliases for: Royal Caribbean Group (RCL)
# ['Royal Caribbean Cruises Ltd.', 'Royal Caribbean Cruises', 'RCL', 'RCCL Group', 'RCL Corporate']
# [406/503] Fetching aliases for: S&P Global (SPGI)
# ['S&P Global Inc.', 'SPGI', 'Seek & Prosper']
# [407/503] Fetching aliases for: Salesforce (CRM)
# ['Salesforce.com, Inc.', 'SFDC', 'salesforce.com']
# [408/503] Fetching aliases for: SBA Communications (SBAC)
# ['SBA Communications Corporation']
# [409/503] Fetching aliases for: Schlumberger (SLB)
# ['Schlumberger Limited', 'Schlumberger Technology Corporation', 'SCHLUMBERGER TECHNOLOGY CORPORATION (Sugar Land, TX)']
# [410/503] Fetching aliases for: Seagate Technology (STX)
# ['Seagate Technology PLC', 'Seagate', 'Shugart Technology', 'Seagate Technology LLC', 'Seagate Technology LLC (Fremont, CA)', 'Seagate Technology Inc.']
# [411/503] Fetching aliases for: Sempra (SRE)
# []
# [412/503] Fetching aliases for: ServiceNow (NOW)
# ['servicenow.com', 'ServiceNow Inc.', 'ServiceNow, Inc.']
# [413/503] Fetching aliases for: Sherwin-Williams (SHW)
# ['Sherwin-Williams Company', 'Sherwin Williams']
# [414/503] Fetching aliases for: Simon Property Group (SPG)
# ['United Society for the Propagation of the Gospel', 'USPG', 'SPG', 'Society for the Propagation of the Gospel']
# [415/503] Fetching aliases for: Skyworks Solutions (SWKS)
# []
# [416/503] Fetching aliases for: J.M. Smucker Company (The) (SJM)
# []
# [417/503] Fetching aliases for: Smurfit Westrock (SW)
# ['Smurfit Kappa']
# [418/503] Fetching aliases for: Snap-on (SNA)
# []
# [419/503] Fetching aliases for: Solventum (SOLV)
# ['Solvay Pharmaceuticals']
# [420/503] Fetching aliases for: Southern Company (SO)
# []
# [421/503] Fetching aliases for: Southwest Airlines (LUV)
# ['Southwest Airlines Co.', 'Southwest']
# [422/503] Fetching aliases for: Stanley Black & Decker (SWK)
# ['The Stanley Works', 'Stanley Works', 'Stanley Black & Decker, Inc.']
# [423/503] Fetching aliases for: Starbucks (SBUX)
# ['Starbucks Corporation', 'Starbucks Coffee', 'Starbucks Coffee Company']
# [424/503] Fetching aliases for: State Street Corporation (STT)
# ['State Street', 'STT']
# [425/503] Fetching aliases for: Steel Dynamics (STLD)
# ['SDI']
# [426/503] Fetching aliases for: Steris (STE)
# []
# [427/503] Fetching aliases for: Stryker Corporation (SYK)
# []
# [428/503] Fetching aliases for: Supermicro (SMCI)
# ['SuperMicro', 'Super Micro Computer', 'Super Micro Computer, Inc.']
# [429/503] Fetching aliases for: Synchrony Financial (SYF)
# []
# [430/503] Fetching aliases for: Synopsys (SNPS)
# ['Synopsys, Inc.', 'SNPS', 'SYNOPSYS, INC. (Mountain View, CA)']
# [431/503] Fetching aliases for: Sysco (SYY)
# ['Sysco Corporation']
# [432/503] Fetching aliases for: T-Mobile US (TMUS)
# ['T-Mobile', 'VoiceStream Wireless', 'T-Mobile USA, Inc.']
# [433/503] Fetching aliases for: T. Rowe Price (TROW)
# ['T. Rowe Price Associates, Inc.', 'T. Rowe Price Group, Inc.']
# [434/503] Fetching aliases for: Take-Two Interactive (TTWO)
# ['Blue Shift, Inc.', 'Visual Concepts Blue Shift', 'Take-Two Interactive Software Vancouver ULC']
# [435/503] Fetching aliases for: Tapestry, Inc. (TPR)
# ['Tapestry', 'Coach, Inc.']
# [436/503] Fetching aliases for: Targa Resources (TRGP)
# []
# [437/503] Fetching aliases for: Target Corporation (TGT)
# []
# [438/503] Fetching aliases for: TE Connectivity (TEL)
# ['Tyco Electronics', 'AMP Incorporated']
# [439/503] Fetching aliases for: Teledyne Technologies (TDY)
# ['Teledyne Technologies, Inc.', 'Teledyne Benthos', 'RD Instruments']
# [440/503] Fetching aliases for: Teradyne (TER)
# []
# [441/503] Fetching aliases for: Tesla, Inc. (TSLA)
# ['Tesla Inc.', 'Tesla']
# [442/503] Fetching aliases for: Texas Instruments (TXN)
# []
# [443/503] Fetching aliases for: Texas Pacific Land Corporation (TPL)
# ['TPL']
# [444/503] Fetching aliases for: Textron (TXT)
# ['Avco Lycoming', 'Textron Lycoming', 'Lycoming Engines', 'Demorest Manufacturing Company', 'Demorest Fashion and Sewing-Machine Company', 'Lycoming Foundry and Machine Company']
# [445/503] Fetching aliases for: Thermo Fisher Scientific (TMO)
# ['Thermo Fisher', 'ThermoFisher', 'TMO']
# [446/503] Fetching aliases for: TJX Companies (TJX)
# []
# [447/503] Fetching aliases for: TKO Group Holdings (TKO)
# []
# [448/503] Fetching aliases for: Tractor Supply (TSCO)
# ['TSCO']
# [449/503] Fetching aliases for: Trane Technologies (TT)
# []
# [450/503] Fetching aliases for: TransDigm Group (TDG)
# ['TransDigm Group Incorporated', 'TDG', 'TransDigm Group']
# [451/503] Fetching aliases for: Travelers Companies (The) (TRV)
# []
# [452/503] Fetching aliases for: Trimble Inc. (TRMB)
# []
# [453/503] Fetching aliases for: Truist Financial (TFC)
# ['BB&T Corporation', 'BBT', 'Branch Banking and Trust Company']
# [454/503] Fetching aliases for: Tyler Technologies (TYL)
# []
# [455/503] Fetching aliases for: Tyson Foods (TSN)
# ['Tyson Foods, Inc.']
# [456/503] Fetching aliases for: U.S. Bancorp (USB)
# ['U.S. Bank']
# [457/503] Fetching aliases for: Uber (UBER)
# ['Uber Technologies, Inc.', 'UberCab', 'Uber Technologies, Inc. (San Francisco, CA)', 'Uber Technology']
# [458/503] Fetching aliases for: UDR, Inc. (UDR)
# []
# [459/503] Fetching aliases for: Ulta Beauty (ULTA)
# ['Ulta Beauty Inc.', 'Ulta']
# [460/503] Fetching aliases for: Union Pacific Corporation (UNP)
# ['Union Pacific and North-Western Line']
# [461/503] Fetching aliases for: United Airlines Holdings (UAL)
# ['UCH', 'United Continental', 'UAL Corporation', 'United Continental Holdings']
# [462/503] Fetching aliases for: United Parcel Service (UPS)
# ['UPS', 'United Parcel Service Inc.', 'United Parcel Service, Inc, UPS', 'UNITED PARCEL SERVICE OF AMERICA, INC. (Atlanta, GA)', 'Merchants Parcel Delivery', 'American Messenger Company']
# [463/503] Fetching aliases for: United Rentals (URI)
# ['United Rentals, Inc']
# [464/503] Fetching aliases for: UnitedHealth Group (UNH)
# ['UnitedHealth Group Inc.']
# [465/503] Fetching aliases for: Universal Health Services (UHS)
# []
# [466/503] Fetching aliases for: Valero Energy (VLO)
# []
# [467/503] Fetching aliases for: Ventas (VTR)
# []
# [468/503] Fetching aliases for: Veralto (VLTO)
# []
# [469/503] Fetching aliases for: Verisign (VRSN)
# ['VeriSign', 'VeriSign,Inc.', 'Verisign, Inc.', 'VRSN']
# [470/503] Fetching aliases for: Verisk Analytics (VRSK)
# ['Verisk Analytics, Inc.']
# [471/503] Fetching aliases for: Verizon (VZ)
# ['Verizon Communications Inc.', 'Bell Atlantic', 'Verizon']
# [472/503] Fetching aliases for: Vertex Pharmaceuticals (VRTX)
# ['Vertex Pharmaceuticals Inc.', 'Vertex']
# [473/503] Fetching aliases for: Viatris (VTRS)
# ['Viatris Inc.', 'Viatris Pharmaceuticals', 'Viatris (firma)']
# [474/503] Fetching aliases for: Vici Properties (VICI)
# []
# [475/503] Fetching aliases for: Visa Inc. (V)
# ['Visa', 'Visa Inc']
# [476/503] Fetching aliases for: Vistra Corp. (VST)
# ['Vistra Corp.', 'Vistra Energy Corp.', 'Vistra Corp']
# [477/503] Fetching aliases for: Vulcan Materials Company (VMC)
# []
# [478/503] Fetching aliases for: W. R. Berkley Corporation (WRB)
# ['W. R. Berkley Corporation', 'Berkley']
# [479/503] Fetching aliases for: W. W. Grainger (GWW)
# ['W. W. Grainger, Inc.', 'Grainger', 'Graigner']
# [480/503] Fetching aliases for: Wabtec (WAB)
# ['Wabtec Corporation']
# [481/503] Fetching aliases for: Walgreens Boots Alliance (WBA)
# []
# [482/503] Fetching aliases for: Walmart (WMT)
# ['Wal-Mart', 'Wal Mart', 'Wal-Mart Stores, Inc.', 'Walmart, Inc.', 'Walmart Inc.', 'Wallmart', 'Wal-mart', 'Wall Mart', 'Wall-Mart']
# [483/503] Fetching aliases for: Walt Disney Company (The) (DIS)
# ['Disney', 'Disney Brothers Cartoon Studio', 'The Walt Disney Studio', 'Walt Disney Productions', 'Walt Disney Company', 'Walt Disney']
# [484/503] Fetching aliases for: Warner Bros. Discovery (WBD)
# ['Turner Broadcasting System Netherlands', 'Turner Europe, Middle East and Africa']
# [485/503] Fetching aliases for: Waste Management (WM)
# ['Waste Management']
# [486/503] Fetching aliases for: Waters Corporation (WAT)
# []
# [487/503] Fetching aliases for: WEC Energy Group (WEC)
# ['WEC Energy Group Inc.', 'Wisconsin Energy Corporation']
# [488/503] Fetching aliases for: Wells Fargo (WFC)
# ['Wells Fargo & Company', 'Wells Fargo Bank']
# [489/503] Fetching aliases for: Welltower (WELL)
# ['wellcome.ac.uk', 'The Wellcome Trust', 'wellcome.org']
# [490/503] Fetching aliases for: West Pharmaceutical Services (WST)
# []
# [491/503] Fetching aliases for: Western Digital (WDC)
# ['Western Digital Corporation', 'WD', 'WDC', 'Western Digital Corp.', 'WD Corp.', 'Western Digital Technologies, Inc.  (San Jose, CA)']
# [492/503] Fetching aliases for: Weyerhaeuser (WY)
# ['Weyerhaeuser Company']
# [493/503] Fetching aliases for: Williams-Sonoma, Inc. (WSM)
# ['Williams Sonoma', 'Willams and Sonoma', 'Williams-Sonoma, Inc', 'Williams-Sonoma']
# [494/503] Fetching aliases for: Williams Companies (WMB)
# ['WMBE', 'Wikimedia Belgium NPO', 'bewikimedia']
# [495/503] Fetching aliases for: Willis Towers Watson (WTW)
# ['Willis (United Kingdom)', 'WTW', 'wtw', 'Willis Towers Watson plc']
# [496/503] Fetching aliases for: Workday, Inc. (WDAY)
# ['Workday', 'workday.com']
# [497/503] Fetching aliases for: Wynn Resorts (WYNN)
# ['Wynn Resorts Limited']
# [498/503] Fetching aliases for: Xcel Energy (XEL)
# []
# [499/503] Fetching aliases for: Xylem Inc. (XYL)
# ['Xylem', 'Xylem (United States)']
# [500/503] Fetching aliases for: Yum! Brands (YUM)
# []
# [501/503] Fetching aliases for: Zebra Technologies (ZBRA)
# []
# [502/503] Fetching aliases for: Zimmer Biomet (ZBH)
# ['Zimmer', 'Biomet', 'Zimmer Biomet', 'Zimmer Biomet Holdings, Inc.']
# [503/503] Fetching aliases for: Zoetis (ZTS)
# ['Zoetis Inc.']
#   Ticker                 Company  \
# 0    MMM                      3M
# 1    AOS             A. O. Smith
# 2    ABT     Abbott Laboratories
# 3   ABBV                  AbbVie
# 4    ACN               Accenture
# 5   ADBE              Adobe Inc.
# 6    AMD  Advanced Micro Devices
# 7    AES         AES Corporation
# 8    AFL                   Aflac
# 9      A    Agilent Technologies
#
#                                              Aliases
# 0  [Minnesota Mining and Manufacturing, Minnesota...
# 1  [A. O. Smith Corporation, A.O. Smith, A.O. Smi...
# 2  [Abbott Labs, Abbott Laboratories, Inc., Ross ...
# 3                                [AbbVie Inc., ABBV]
# 4  [Accenture Global Solutions Limited (Dublin), ...
# 5  [Adobe Systems, Adobe Systems, Inc., Adobe Sys...
# 6                           [Advanced Micro Devices]
# 7  [AES Corp., The AES Corporation, AES Corp, AES...
# 8           [American Family Life Assurance Company]
# 9                       [Agilent Technologies, Inc.]

# %%
import pandas as pd
import re
import ast

df = pd.read_csv('sp500_with_wikidata_aliases.csv')

remove_words = [
    'The', 'Inc', 'Corporation', 'Corp', 'Ltd', 'Limited', 'Group', 'Co', 'PLC', 'LLC', 'and', 'GmbH'
]

def clean_company_name(company_name):
    company_name = re.sub(r'[.,]', '', company_name)  
    pattern = r'\b(?:' + '|'.join(re.escape(word) for word in remove_words) + r')\b'
    company_name = re.sub(pattern, '', company_name, flags=re.IGNORECASE)
    company_name = re.sub(r'\s+', ' ', company_name).strip()
    return company_name

def append_cleaned_aliases(row):
    current_aliases = row['Aliases']
    if isinstance(current_aliases, str): 
        try:
            current_aliases = ast.literal_eval(current_aliases)
        except:
            current_aliases = []
    
    cleaned_name = clean_company_name(row['Company'])
    
    if cleaned_name and not any(cleaned_name.lower() == alias.lower() for alias in current_aliases):
        current_aliases.append(cleaned_name)
        
    return current_aliases

df['Aliases'] = df.apply(append_cleaned_aliases, axis=1)

df.to_csv('sp500_with_appended_aliases.csv', index=False)

print(df[df['Company'].str.contains('Apple', case=False)][['Company', 'Aliases']])
# Out:
#        Company                                            Aliases
# 39  Apple Inc.  [Apple Computer Inc, Apple Incorporated, Apple...
